# %%
#using OOPS a programmer can creates its own type of data types

# %%
#every data types in python are built in classes,  when we make a varibales of this data type like L=[1,2,3] then L is a object of that class  here list is class and L is a object

# %%
#class is blueprint that stat that how their object behaves

# %%
# class
# /     \
# Data   Functions or behavior
# or property

# %%
#object is an istance of class

# %%
# syntax to create an object
# objectname=classname()

# %%
#1. class ke andar koi bhi variable bnane hai to use constructor ke andar bnaoge
#2. variable se pahe self. lgayenge

class Atm:
  #constructor(special function)>> super power -> we do not need to calll the function ye outmacticallly execute ho jata hai
  def __init__(self):
    self.pin=""
    self.balance=0
    self.menu()

  def menu(self):
    user_input= input("""
    Hi how can I help you
    1. press 1 to create pin
    2. press 2 to change pin
    3. press 3 to check balance
    4. press 4 to withdraw
    5. anything else to exit
    """)
    if user_input=='1':
      #create pin
      self.create_pin()
    elif user_input =='2':
      self.change_pin()
    elif user_input =='3':
        self.check_balance()

    elif user_input =='4':
      self.withdraw()
    else:
      pass
      exit()

  def create_pin(self):
    user_pin=input("enter your pin")
    self.pin=user_pin

    user_balance=int(input('enter your balance'))
    self.balance=user_balance

    print('pin created succesfully')
    self.menu()

  def change_pin(self):
    old_pin=input('enter old pin')
    if old_pin==self.pin:
      #let him to chnage the pin
      new_pin=input('enter new pin')
      self.pin=new_pin
      print('pin change successful')
      self.menu()

    else:
      print('wrong pin')
      self.menu()

  def check_balance(self):
    user_pin=input('enter your pin')
    if user_pin==self.pin:
      print('your balance is ',self.balance)
    else:
      print("chal nikal")

  def withdraw(self):
   user_pin= input('enter the pin')
   if self.pin==self.pin:
    amount=int(input('enter your balance'))
    if amount<=self.balance:
      self.balance=self.balance-amount
      # print('withdraw successful.balance is' self.balance)
      print('withdraw succesful balance is', self.balance)
    else:
      print('abe garib')

   else:
      print('sale chor')

# %%
obj=Atm()
# Out:
#     Hi how can I help you
#     1. press 1 to create pin
#     2. press 2 to change pin
#     3. press 3 to check balance
#     4. press 4 to withdraw
#     5. anything else to exit
#     1
# enter your pin1234
# enter your balance1000
# pin created succesfully
#
#     Hi how can I help you
#     1. press 1 to create pin
#     2. press 2 to change pin
#     3. press 3 to check balance
#     4. press 4 to withdraw
#     5. anything else to exit
#     4
# enter the pin1234
# enter your balance500
# withdraw succesful balance is 500

# %%
type(obj)
# Out:
# __main__.Atm

# %%
#class ke andar ke function ko ham method bulate hai and clas ke bahar jo bhi functions hai unhe function bulate hai

# %%
l=[1,2,3]
len(l)#function ->bcz it is outside the list class
l.append(1)#method -> bcz it is inside the list class

# %%
# True use of constructor is write configuration like code means connectiing to the internet , connecting to the database because when app start id direclty trigger no control of user in this

# %%
#hmare class ke jo bhi data hai aur methods hai vo sirf us class ka object hi access kar sakta hai

# %%
#self hame ye power deta hai ki kal agar mere hi ek method ko dusre method se bat karni hai to hm self ka use karte hai actually hmare object aur self same hi hai ye hm verify kar sakte hai uske location se kyuki dono ka locaation same hi aayega

# %%
# OOps bolta hai ki aapke class ke ek method dusre method se bat nahi kar sakte hai aur usi bat chit ko sablize karne ke liye u need an object of the class inside of that class isiliye ham self ka use karte hai

# %%
#  u can say for intracommunication we use self

# %% [markdown]
# # Fraction data type

# %%
class fraction:

  #parameterized constructor ->> aisa constructor jisko input ki jarurat hoti hai
  def __init__(self,x,y):
    self.num=x
    self.den=y

  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    new_num=self.num*other.den + other.num*self.den
    new_den=self.den*other.den
    return '{}/{}'.format(new_num,new_den)

  def __sub__(self,other):
    new_num=self.num*other.den - other.num*self.den
    new_den=self.den*other.den
    return '{}/{}'.format(new_num,new_den)

  def __mul__(self,other):
    new_num=self.num*other.num
    new_den=self.den*other.den
    return '{}/{}'.format(new_num,new_den)

  def __truediv__(self,other):
    new_num=self.num*other.den
    new_den=self.den*other.num
    return '{}/{}'.format(new_num,new_den)


  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1=fraction(7,3)
fr2=fraction(1,2)

# %%
print(fr1)
# Out:
# 3/4

# %%
print(fr1 + fr2)
# Out:
# 10/8

# %%
print(fr1 - fr2)
print(fr1 * fr2)
print(fr1 / fr2)
# Out:
# 11/6
# 7/6
# 14/3

# %%
fr1.convert_to_decimal()
# Out:
# 2.3333333333333335
